# %% [markdown]
# # Matplotlib Basics

# %%
# %matplotlib notebook
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
average_temperatures = np.random.randint(0,10000,12) / 100

# %%
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']

# %%
average_temperatures
# Out:
# array([18.  , 94.17, 55.09, 45.45, 80.1 , 15.81,  5.04, 72.79, 68.92,
#        27.26, 23.58, 51.73])

# %%
plt.figure(figsize = (12,5))
plt.plot(months,average_temperatures, marker='o', linestyle='--')
plt.title('Average monthly temperatures')
plt.xlabel('Months')
plt.ylabel('Temperatures')
plt.grid(True)
plt.savefig('average_monthly_temperatures.png')
plt.savefig('average_monthly_temperatures.pdf')
plt.show()

# %%
fig

# %%
books1 = np.random.randint(1,20,12)
books2 = np.random.randint(1,20,12)

# %%
books1
# Out:
# array([ 8,  7,  7,  3, 18,  4, 18, 11, 13, 18,  1,  9])

# %%
books2
# Out:
# array([ 8,  5,  1, 15, 19,  2, 14,  6,  9, 10,  3,  3])

# %%
fig = plt.figure(figsize = (12,6))
plt.plot(months,books1,label='books student 1', marker = 'o', linestyle = '--')
plt.plot(months,books2,label='books student 2', marker = 'o')
plt.title('Books read in 2021')
plt.xlabel('Months')
plt.ylabel('No of books read')
plt.legend()
plt.grid(True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[103], line 4
#       2 plt.plot(months,books1,label='books student 1', marker = 'o', linestyle = '--')
#       3 plt.plot(months,books2,label='books student 2', marker = 'o')
# ----> 4 plt.title('Average monthly temperatures')
#       5 plt.xlabel('Months')
#       6 plt.ylabel('Temperatures')
#
# TypeError: 'str' object is not callable
